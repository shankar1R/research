# %%
import pandas as pd

# Loding data from csv through pd.read_csv
Data=pd.read_csv("C:/Users/User/Desktop/Rsearch/Manufactering dataset/archive (8)/Car Data.csv")
Data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17148\2113106279.py in <module>
#       2
#       3 # Loding data from csv through pd.read_csv
# ----> 4 Data=pd.read_csv("C:/Users/User/Desktop/Rsearch/Manufactering dataset/archive (8)/Car Data.csv")
#       5 Data
#
# ...

# %%
import pandas as pd

# Loding data from csv through pd.read_csv
Data=pd.read_csv("C:/Users/User/Desktop/Rsearch/Manufactering dataset/archive (9)/concrete.csv")
Data
# Out:
#       cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0      141.3  212.0    0.0  203.5           0.0      971.8    748.5   28
# 1      168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 2      250.0    0.0   95.7  187.4           5.5      956.9    861.2   28
# 3      266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
# 4      154.8  183.4    0.0  193.3           9.1     1047.4    696.7   28
# ...      ...    ...    ...    ...           ...        ...      ...  ...
# 1025   135.0    0.0  166.0  180.0          10.0      961.0    805.0   28
# 1026   531.3    0.0    0.0  141.8          28.2      852.1    893.7    3
# 1027   276.4  116.0   90.3  179.6           8.9      870.1    768.3   28
# 1028   342.0   38.0    0.0  228.0           0.0      932.0    670.0  270
# 1029   540.0    0.0    0.0  173.0           0.0     1125.0    613.0    7
#
#       strength
# 0        29.89
# 1        23.51
# 2        29.22
# 3        45.85
# ...
