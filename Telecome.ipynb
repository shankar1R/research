# %%
import pandas as pd

# Loding data from csv through pd.read_csv
Data=pd.read_csv("C:/Users/User/Desktop/Rsearch/telecom data set/archive (8)/churn-bigml-80.csv")
Data
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 2661    SC              79        415                 No              No
# 2662    AZ             192        415                 No             Yes
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
import pandas as pd

# Loding data from csv through pd.read_csv
Data=pd.read_csv("C:/Users/User/Desktop/Rsearch/telecom data set/archive (9)/Telecom_customer churn.csv")
Data
# Out:
#        rev_Mean  mou_Mean  totmrc_Mean  da_Mean  ovrmou_Mean  ovrrev_Mean  \
# 0       23.9975    219.25       22.500   0.2475         0.00          0.0
# 1       57.4925    482.75       37.425   0.2475        22.75          9.1
# 2       16.9900     10.25       16.990   0.0000         0.00          0.0
# 3       38.0000      7.50       38.000   0.0000         0.00          0.0
# 4       55.2300    570.50       71.980   0.0000         0.00          0.0
# ...         ...       ...          ...      ...          ...          ...
# 99995       NaN       NaN          NaN      NaN          NaN          NaN
# 99996       NaN       NaN          NaN      NaN          NaN          NaN
# 99997       NaN       NaN          NaN      NaN          NaN          NaN
# 99998       NaN       NaN          NaN      NaN          NaN          NaN
# 99999       NaN       NaN          NaN      NaN          NaN          NaN
#
#        vceovr_Mean  datovr_Mean  roam_Mean  change_mou  ...  forgntvl  ethnic  \
# ...
